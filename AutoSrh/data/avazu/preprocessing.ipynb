# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('train')

# %%
train_df.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain  ... device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9  ...           1                2  15706
# 1      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 2      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 3      28905ebd  ecad2386   7801e8d9  ...           1                0  15706
# 4      0569f928  ecad2386   7801e8d9  ...           1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# ...

# %%
train_df['device_id'].unique().shape
# Out:
# (2686408,)

# %%
train_df.shape
# Out:
# (40428967, 24)

# %%
train_df['device_ip'].unique().shape
# Out:
# (6729486,)

# %%
train_df['device_model'].unique().shape
# Out:
# (8251,)

# %%
train_df_gb_uid = train_df.groupby('device_id', group_keys=False)

# %%
train_df_gb_uid.count()['id'].describe()
# Out:
# count    2.686408e+06
# mean     1.504945e+01
# std      2.035252e+04
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      3.335831e+07
# Name: id, dtype: float64

# %%
train_df_le_10 = train_df_gb_uid.filter(lambda x: len(x)>=10)

# %%
train_df_le_10.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
train_df_le_10.groupby('device_id').count()['id'].describe()
# Out:
# count    1.014480e+05
# mean     3.527245e+02
# std      1.047327e+05
# min      1.000000e+01
# 25%      1.200000e+01
# 50%      1.500000e+01
# 75%      2.400000e+01
# max      3.335831e+07
# Name: id, dtype: float64

# %%
train_df_le_10.shape
# Out:
# (35783194, 24)

# %%
train_df_le_30 = train_df_le_10.groupby('device_id').filter(lambda x: len(x)>=30)

# %%
train_df_le_30.groupby('device_id').count()['id'].describe()
# Out:
# count    1.715600e+04
# mean     2.010538e+03
# std      2.546803e+05
# min      3.000000e+01
# 25%      3.500000e+01
# 50%      4.300000e+01
# 75%      6.100000e+01
# max      3.335831e+07
# Name: id, dtype: float64

# %%
train_df_se_3e7 = train_df_le_30.groupby('device_id').filter(lambda x: len(x)<3e7)

# %%
train_df_se_3e7.shape
# Out:
# (1134477, 24)

# %%
train_df_se_3e7.groupby('device_id').count()['id'].describe()
# Out:
# count    17155.000000
# mean        66.130982
# std        273.640155
# min         30.000000
# 25%         35.000000
# 50%         43.000000
# 75%         61.000000
# max      21356.000000
# Name: id, dtype: float64

# %%
train_df_se_3e7[train_df_se_3e7['click']==0].shape
# Out:
# (1012185, 24)

# %%
train_df_se_3e7 = train_df_se_3e7.rename(columns={'device_id': 'uid', 'id': 'iid'})

# %%
train_df_se_3e7.columns
# Out:
# Index(['iid', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'uid',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
new_columns_order  = ['click', 'uid', 'C1', 'banner_pos', 'site_id', 'site_domain',
       'site_category', 'app_id', 'app_domain', 'app_category', 'device_model', 'device_type', 'device_conn_type', 'C14',
       'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21']
train_df_se_3e7_newOrder = train_df_se_3e7[new_columns_order]

# %%
train_df_se_3e7_newOrder.head()
# Out:
#     click       uid    C1  banner_pos   site_id site_domain site_category  \
# 9       0  c357dbff  1002           0  84c7ba46    c4e18dd6      50e219e0
# 25      0  fb23c543  1010           1  85f751fd    c4e18dd6      50e219e0
# 27      1  9af87478  1005           0  85f751fd    c4e18dd6      50e219e0
# 35      0  4b2309e9  1005           0  85f751fd    c4e18dd6      50e219e0
# 42      0  432cd280  1005           0  85f751fd    c4e18dd6      50e219e0
#
#       app_id app_domain app_category  ... device_type  device_conn_type  \
# 9   ecad2386   7801e8d9     07d7df22  ...           0                 0
# 25  ffc6ffd0   7801e8d9     0f2161f8  ...           4                 0
# 27  54c5d545   2347f47a     0f2161f8  ...           1                 0
# 35  d2bb6502   2347f47a     8ded1f7a  ...           1                 3
# 42  e2a1ca37   2347f47a     8ded1f7a  ...           1                 0
#
#       C14  C15  C16   C17  C18  C19     C20  C21
# ...

# %%
last_max=-1
for col in train_df_se_3e7_newOrder.columns.values[1:]:
    train_df_se_3e7_newOrder[col]=train_df_se_3e7_newOrder[col].astype("category").cat.codes
    train_df_se_3e7_newOrder[col]+=last_max+1
    last_max = train_df_se_3e7_newOrder[col].max()
# Out:
# /home/chengweiyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/chengweiyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/chengweiyu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
train_df_se_3e7_newOrder.describe()
# Out:
#               click           uid            C1    banner_pos       site_id  \
# count  1.134477e+06  1.134477e+06  1.134477e+06  1.134477e+06  1.134477e+06
# mean   1.077959e-01  8.540657e+03  1.715712e+04  1.716219e+04  1.753070e+04
# std    3.101226e-01  4.986362e+03  1.055150e+00  3.964429e-01  6.570701e+01
# min    0.000000e+00  0.000000e+00  1.715500e+04  1.716200e+04  1.716600e+04
# 25%    0.000000e+00  4.116000e+03  1.715700e+04  1.716200e+04  1.753900e+04
# 50%    0.000000e+00  8.742000e+03  1.715700e+04  1.716200e+04  1.753900e+04
# 75%    0.000000e+00  1.293200e+04  1.715700e+04  1.716200e+04  1.753900e+04
# max    1.000000e+00  1.715400e+04  1.716100e+04  1.716500e+04  1.787200e+04
#
#         site_domain  site_category        app_id    app_domain  app_category  \
# count  1.134477e+06   1.134477e+06  1.134477e+06  1.134477e+06  1.134477e+06
# mean   1.860248e+04   1.883000e+04  1.922843e+04  1.959836e+04  1.965534e+04
# ...

# %%
train_df_se_3e7_newOrder=train_df_se_3e7_newOrder.rename(columns={'click': 'is_click'})

# %%
id_cols = train_df_se_3e7_newOrder.columns.values[1:]
for col in id_cols:
    train_df_se_3e7_newOrder[col+'_val']=pd.Series(1, train_df_se_3e7_newOrder[col].index)

# %%
train_df_se_3e7_newOrder.head()
# Out:
#     is_click    uid     C1  banner_pos  site_id  site_domain  site_category  \
# 9          0  13123  17156       17162    17533        18620          18830
# 25         0  16808  17160       17163    17539        18620          18830
# 27         1  10422  17157       17162    17539        18620          18830
# 35         0   5059  17157       17162    17539        18620          18830
# 42         0   4533  17157       17162    17539        18620          18830
#
#     app_id  app_domain  app_category  ...  device_type_val  \
# 9    19530       19605         19650  ...                1
# 25   19579       19605         19652  ...                1
# 27   19056       19587         19652  ...                1
# 35   19438       19587         19662  ...                1
# 42   19490       19587         19662  ...                1
#
#     device_conn_type_val  C14_val  C15_val  C16_val  C17_val  C18_val  \
# 9                      1        1        1        1        1        1
# ...

# %%
train_df_se_3e7_newOrder.to_csv('avazu.csv', index=False)
